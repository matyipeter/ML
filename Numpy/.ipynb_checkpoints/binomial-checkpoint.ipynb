# %%
import numpy as np
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = random.binomial(n=10, p=0.8, size=10000)
print(x)
# Out:
# [7 8 9 ... 7 9 9]

# %%
sns.kdeplot(x)
plt.show()

# %%
np.sum(x)
# Out:
# 80094
